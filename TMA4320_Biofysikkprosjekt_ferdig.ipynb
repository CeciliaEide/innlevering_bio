# %% [markdown]
# # TMA4320: Biofysikkprosjekt
# Av: Ingrid M. Løvold, Oskar Farbrot og Cecilia M. B. Eide

# %% [markdown]
# ## Introduksjon
# I dette prosjektet har vi benyttet Monte Carlo-metode for å simulere polymerfolding. Polymerer er kjemiske forbindelser som er bygd opp av store kjedeformede molekyler man kaller monomerer. DNA, RNA og proteiner er eksempler på naturlige polymerer, så ved å forstå mer om polymerer kan vi også lære mer om grunnlaget til levende organismer. Vi bruker en forenklet 2D modell, med monomerene som punktverdier i et koordinatsystem. Vi vil se på hvordan temperaturen påvirker polymerfolding, samt diskutere hvor gode modellene våre er.

# %% [markdown]
# ## Modell for polymerfolding
# Begynner med å importere nødvendige biblioteker.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import time

# %% [markdown]
# For å representere en polymer numerisk bruker vi et array av posisjonskoordinatene til hvert monomer. Det er et N x 2 array, der N er antall monomerer, og vi får N elementer av posisjonsvektorer på formen [x, y]. Indeksen i arrayet viser gjennomgående til et spesifikt monomers posisjon. Vi slipper da å lagre og vurdere alle de tomme posisjonene i koordinatsystemet og får en mer effektiv kode. Vi bruker et diskret koordinatsystem som er et kvadratisk gitter med avstand lik 1.
#
# I flere av simuleringene tar vi utgangspunkt i en rett polymer og definerer derfor funksjonen makeStraightPolymer(N) som vist i kodeblokken under. Denne tar inn antall monomerer i polymeren, N, og gir ut en horisontal polymer midt i et koordinatsystem med størrelse N x N. Er N et partall vil den legge seg på den øverste av de to midterste radene, men dette påvirker ikke koden videre.

# %%
def makeStraightPolymer(N): #Make a straight polymer with length N
    y = int(N/2) + 1 #arrange at 1/2 of length in y-direction (middle, depending on odd/even N)
    koord = np.zeros((N, 2), dtype=int)
    
    for i in range(N):
        koord[i] = [i+1, y]
    
    return koord #N x 2 matrix containing coordinates for monomer 1-N position, indexed 0 - (N-1)

# %% [markdown]
# En folding simuleres ved gjentatte rotasjoner av en ende av polymeret om en tilfeldig valgt monomer. Disse rotasjonene er forenklet ved at de foregår i et 2D-plan og at de alltid vil være en knekk på 90 grader, enten med eller mot klokka. Funksjonen rotatePolymer(polymer, koord, rot) tar inn en polymer, en tilfeldig rotasjonsretning og en tilfeldig monomer polymeret skal rotere om. Dette kommer vi tilbake til senere i prosjektet. Vi roterer alltid den korteste delen av polymeren slik at vi ikke havner utenfor koordinatsystemet vi har laget. Det blir ingen fysisk forskjell på å rotere den korte enden i en rotasjonsretning og på å rotere den lange enden i motsatt rotasjonsretning fordi sluttposisjonen blir lik, bare med annen orientering i rommet. Siden rotasjonsretning er tilfeldig kan vi dermed velge å alltid rotere den korte delen uten at det endrer resultatet.
#
# Vi ser også bort ifra rotasjoner om endemonomerene fordi det ikke gir noen energiendring. En eventuell energiendring for polymeren skyldes svake vekselvirkninger mellom monomerer som ikke allerede er bundet av kovalente bindinger. En rotasjon rundt et endepunkt på polymeren vil ikke gi en energiendring, da ingen monomerer endrer posisjoner relativt til hverandre og derfor ikke vil oppleve noen endrede vekselvirkninger.
#
# Polymeren som system ønsker å minimere energien sin, og senere i oppgaven vil vi se at den som hovedregel kun endrer
# tilstand dersom den totale energiendringen er mindre enn null. Dersom en rotasjon om et endepunkt likevel inntreffer
# grunnet termiske fluktuasjoner som tillater ugunstige endringer, kan vi dessuten også se at dette ikke utgjør en reell
# endring for systemet vi simulerer. Vår løsning av oppgaven velger, som nevnt, alltid å rotere den korteste enden fra rotasjonsmonomeren,
# som for et endepunkt ikke vil inneholde noen monomerer i det hele tatt og derfor åpenbart ikke endre polymeren. Skulle vi
# likevel valgt å rotere den lengste enden, vil heller ikke monomerenes posisjoner endres relativt til hverandre. Å tillate
# en slik rotasjon i simuleringen vil være det samme som å endre polymerens orientering i koordinatsystemet, og utgjør ikke
# en reell forskjell for polymeren. Uansett metode vil rotasjon om endepunkt være et urelevant tilfelle, og vi har derfor
# vurdert at det ikke er hensiktsmessig å inkludere koordinater for endemonomerer i utvalget av rotasjonsmonomerer.

# %%
def rotatePolymer(polymer, koord, rot): 
    polymer = np.copy(polymer)
    rot_om = np.where((polymer == koord).all(axis=1))[0][0]
    #for i in range(len(polymer)): #Kan ta (1, len(polymer) - 1) for raskere kode, siden vi ikke tar hensyn til rot om endemonomerer
        #if polymer[i][0] == koord[0] and polymer[i][1] == koord[1]:
            #rot_om = i
        
    if rot_om > len(polymer)/2: #Rotates monomers with index higher than the rotation-coordinate
        for i in range(rot_om + 1, len(polymer)):
            avstandsvektor = polymer[i] - polymer[rot_om]
            
            if rot == True: #Clockwise
                avstandsvektor[0], avstandsvektor[1] = avstandsvektor[1], -avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
            else: #Counter-clockwise
                avstandsvektor[0], avstandsvektor[1] = -avstandsvektor[1], avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
    
    else: #Rotates monomers with index lower than the rotation-coordinate
        for i in range(rot_om):
            avstandsvektor = polymer[rot_om] - polymer[i] 
            if rot == True: #Clockwise
                avstandsvektor[0], avstandsvektor[1] = avstandsvektor[1], avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
            else: #Counter-clockwise
                avstandsvektor[0], avstandsvektor[1] = -avstandsvektor[1], -avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
    return polymer

# %% [markdown]
# Vi har i rotasjonsjonsfunksjonen ikke tatt hensyn til om den nye polymeren er fysisk gyldig. En polymer skal være sammenhengende og den skal ikke foldes slik at monomerer havner i samme koordinater, slik at de ligger oppå hverandre. Vi har derfor laget funksjonen polymerIntact(polymer, N) som returnerer false dersom to eller flere monomerer ligger i samme koordinat eller om monomerer med kovalent binding, altså monomer med indeks [i] og monomer med indeks [i+1] eller [i-1], ikke er nærmeste nabo. Dette i henhold til oppgave 1 i prosjektbeskrivelsen.
#
# Selv om ikke rotasjonsfunksjonen direkte kontrollerer at polymeren er sammenhengende gir den ikke noe rom for å lage en polymer som ikke er det. Vi har likevel valgt å inkludere en test for dette i polymerIntact for å best mulig besvare oppgaven.

# %%
def polymerIntact(polymer, N): #Checking predefined rules for intact polymer (intact -> True)
    #Checking if polymer contains N monomers
    if len(polymer) != N:
        return False
    
    #Checking if any monomers are overlapping (two or more at same coord.)
    unique_positions = set()
    for monomer in polymer:
        # Convert numpy array to tuple for set insertion
        pos = tuple(monomer)
        unique_positions.add(pos)

    if len(unique_positions) != N:
        return False
    
    #Verifying that each monomer is neighbouring the previos one. (this should always be the case with the way our polymers are made and handeled throughut the project?)
    for i in range(len(polymer) - 1):
        dx = abs(polymer[i][0] - polymer[i + 1][0])
        dy = abs(polymer[i][1] - polymer[i + 1][1])
        if not ((dx == 1 and dy == 0) or (dx == 0 and dy == 1)):
            return False
    
    return True

# %% [markdown]
# Vi har nå satt opp forutsetninger for å simulere en velykket rotasjon av en polymer. Det er derimot mer interresant å se på en simulering med N_s forsøk på rotsasjon, noe vi har satt opp i funksjonen under. Denne tar inn en gyldig polymer, forsøker å folde den et gitt antall ganger (N_s) og returnerer sluttpolymererpolymeren og antall vellykkede rotasjoner. Vi gjør rotasjonsretning og hvilket monomer vi roterer om tilfeldig ved å generere pseudotilfeldige heltall fra numpy.random biblioteket. Denne modellen tar ikke hensyn til polymerens energi, noe vi kommer til senere.

# %%
def N_simuleringer(N, N_s): #simulates N_s rotation attempts of a polymer of length N
    counter = 0
    polymer = makeStraightPolymer(N)
    
    for i in range(N_s):
        koord = polymer[np.random.randint(1, N-1)] #Excludes end-monomers
        rot = np.random.randint(0, 2)
        twisted_polymer = rotatePolymer(polymer, koord, rot)
        
        if polymerIntact(twisted_polymer, N) == True:
            counter += 1
            polymer = twisted_polymer
            
    return polymer, counter

# %% [markdown]
# For å illustrere en polymer, noe vi vil bruke for å vise sluttpolymerene senere i oppgaven, bruker vi funksjonen illustratePolymer(polymer) som vist i kodeblokken under.

# %%
def illustratePolymer(polymer, name):
    
    M = len(polymer) + 2 #Adding to make a finer pLegger til en på hver side for finere plot, derfor + 2
    
    x = np.arange(0, M, 1)
    y = np.arange(0, M, 1)
    
    insertPolymer = np.zeros((M, M))
        
    for i in range(len(polymer)):  
        insertPolymer[int(polymer[i][1])][int(polymer[i][0])] = i+1 #each monomer placed in grid and assigned increasing int values thorughout the chain 
        plt.text(int(polymer[i][0]), int(polymer[i][1]), str(i+1), ha='center', va='center') #print assigned number
    
    plt.title(name)
    plt.pcolormesh(x, y, insertPolymer) #colour distinguish
    plt.show()

# %% [markdown]
# Vi har nå beskrevet metoden vi skal bruke for å simulere en polymerfolding, men simuleringen for polymerfolding må ta høyde for at polymerene kan være lange og rotasjonsforsøkene mange. Vi har derfor utforsket hvordan vi kan skrive en kode med lik funksjonalitet, men som kjører på kortere tid. Vi har også oppdaget at måten vi behandler polymeren og dens rotasjoner i koordinatsystemet gjør det unødvendig å sjekke enkelte av kravene for en intakt polymer, da disse ikke kan bli brutt gjennom programmet. Vi har derfor også inkludert og analysert en versjon av koden som ekskluderer unødvendige sjekker.
#
# Nedenfor er "slow" den initielle koden, "fast" sikter til koden som gjør det samme men kjører raskere. "fastfast" er koden som er optimalisert og samtidig strippet for overflødige sjekker. Videre vil vi sammenligne og diskutere funksjonaliteten til de tre alternativene.

# %%
"""--------------------SLOW--------------------"""
def polymerIntact_s(polymer, N): #Checking predefined rules for intact polymer (intact -> True)
    #Checking if polymer contains N monomers
    if len(polymer) != N:
        return False
    
    #Verefies that monomers not overlap 
    for i in range(len(polymer)-1):
        for j in range(i+1, len(polymer)):
            result_variable = (polymer[i] == polymer[j]).all()
            if result_variable == True:
                return False
    
    #Checks if monomers are in a continuous chain
    test = 0

    for i in range(len(polymer)-1):
        if polymer[i+1][0] == polymer[i][0] and polymer[i+1][1] + 1 == polymer[i][1]:
            test += 1
        elif polymer[i+1][0] == polymer[i][0] and polymer[i+1][1] - 1 == polymer[i][1]:
            test += 1
        elif polymer[i+1][0] + 1 == polymer[i][0] and polymer[i+1][1] == polymer[i][1]:
            test += 1
        elif polymer[i+1][0] - 1 == polymer[i][0] and polymer[i+1][1] == polymer[i][1]:
            test += 1

    if test == len(polymer)-1:
        return True
    else:
        return False
    

def rotatePolymer_s(polymer, koord, rot): 
    polymer = np.copy(polymer)
    for i in range(len(polymer)): 
        if polymer[i][0] == koord[0] and polymer[i][1] == koord[1]:
            rot_om = i
        
    if rot_om > len(polymer)/2: #Rotates monomers with index higher than the rotation-coordinate
        for i in range(rot_om + 1, len(polymer)):
            avstandsvektor = polymer[i] - polymer[rot_om]
            
            if rot == True: #Clockwise
                avstandsvektor[0], avstandsvektor[1] = avstandsvektor[1], -avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
            else: #Counter-clockwise
                avstandsvektor[0], avstandsvektor[1] = -avstandsvektor[1], avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
    
    else: #Rotates monomers with index lower than the rotation-coordinate
        for i in range(rot_om):
            avstandsvektor = polymer[rot_om] - polymer[i] 
            if rot == True: #Clockwise
                avstandsvektor[0], avstandsvektor[1] = avstandsvektor[1], avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
            else: #Counter-clockwise
                avstandsvektor[0], avstandsvektor[1] = -avstandsvektor[1], -avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
    return polymer


def N_simuleringer_s(N, N_s): #simulates N_s rotation attempts of a polymer of length N
    counter = 0
    polymer = makeStraightPolymer(N)
    
    for i in range(N_s):
        koord = polymer[np.random.randint(1, N-1)] #Excludes end-monomers
        rot = np.random.randint(0, 2)
        twisted_polymer = rotatePolymer_s(polymer, koord, rot)
        
        if polymerIntact_s(twisted_polymer, N) == True:
            counter += 1
            polymer = twisted_polymer
            
    return polymer, counter

# %%
'''--------------------FAST--------------------'''
def polymerIntact_f(polymer,N):
    #Sjekker om polymeren har N monomerer    
    if len(polymer) != N:
        return False
    
    #Checking if any monomers are overlapping (two or more at same coord.)
    unique_positions = set()
    for monomer in polymer:
        # Convert numpy array to tuple for set insertion
        pos = tuple(monomer)
        unique_positions.add(pos)

    if len(unique_positions) != N:
        return False
    
    #Verifying that each monomer is neighbouring the previos one. (this should always be the case with the way our polymers are made and handeled throughut the project?)
    for i in range(len(polymer) - 1):
        dx = abs(polymer[i][0] - polymer[i + 1][0])
        dy = abs(polymer[i][1] - polymer[i + 1][1])
        if not ((dx == 1 and dy == 0) or (dx == 0 and dy == 1)):
            return False
        
    return True

def rotatePolymer_f(polymer, koord, rot): 
    polymer = np.copy(polymer)
    rot_om = np.where((polymer == koord).all(axis=1))[0][0] 
        
    if rot_om > len(polymer)/2: #Rotates monomers with index higher than the rotation-coordinate
        for i in range(rot_om + 1, len(polymer)):
            avstandsvektor = polymer[i] - polymer[rot_om]
            
            if rot == True: #Clockwise
                avstandsvektor[0], avstandsvektor[1] = avstandsvektor[1], -avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
            else: #Counter-clockwise
                avstandsvektor[0], avstandsvektor[1] = -avstandsvektor[1], avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
    
    else: #Rotates monomers with index lower than the rotation-coordinate
        for i in range(rot_om):
            avstandsvektor = polymer[rot_om] - polymer[i] 
            if rot == True: #Clockwise
                avstandsvektor[0], avstandsvektor[1] = avstandsvektor[1], avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
            else: #Counter-clockwise
                avstandsvektor[0], avstandsvektor[1] = -avstandsvektor[1], -avstandsvektor[0]
                polymer[i] = polymer[rot_om] + avstandsvektor
            
    return polymer

def N_simuleringer_f(N, N_s): #simulates N_s rotation attempts of a polymer of length N
    counter = 0
    polymer = makeStraightPolymer(N)
    
    for i in range(N_s):
        koord = polymer[np.random.randint(1, N-1)] #Excludes end-monomers
        rot = np.random.randint(0, 2)
        twisted_polymer = rotatePolymer_f(polymer, koord, rot)
        
        if polymerIntact_f(twisted_polymer, N) == True:
            counter += 1
            polymer = twisted_polymer
            
    return polymer, counter

# %%
'''--------------------FASTFAST--------------------'''
def polymerIntact_ff(polymer,N):   
    #Checking if any monomers are overlapping (two or more at same coord.)
    unique_positions = set()
    for monomer in polymer:
        # Convert numpy array to tuple for set insertion
        pos = tuple(monomer)
        unique_positions.add(pos)

    if len(unique_positions) != N:
        return False        
    return True

def N_simuleringer_ff(N, N_s): #simulates N_s rotation attempts of a polymer of length N
    counter = 0
    polymer = makeStraightPolymer(N)
    
    for i in range(N_s):
        koord = polymer[np.random.randint(1, N-1)] #Excludes end-monomers
        rot = np.random.randint(0, 2)
        twisted_polymer = rotatePolymer_f(polymer, koord, rot)
        
        if polymerIntact_ff(twisted_polymer, N) == True:
            counter += 1
            polymer = twisted_polymer
            
    return polymer, counter

# %% [markdown]
# Hovedforskjellen på "slow" og "fast" er bruken av vektoroperasjoner fremfor nøstede løkker. Der "slow" baserer seg på kondisjoner som må testes ved å iterere gjennom alle monomerene, benytter "fast" innebygde numpy-funksjoner som utfører operasjoner på hele arrayet (eller settet) der vi har sett det mulig. Fordelen med "slow" er imidlertid at den for mange kan være enklere å lese, og stegene oppleves mer intuitive da de er en mer direkte oversettelse av vår tenkemåte. Det kan også være enklere å forsikre seg om at koden gjør nøyaktig det du ønsker, da du ikke er avhengig av å stole på funksjonaliteten og din egen kjennskap til innebygde funksjoner. Det er likevel ikke noen tvil om at den raske koden er å foretrekke.
#
# Vi har også valgt å inkludere "fastfast" i denne sammenligningen. I funksjonen polymerIntact tester vi at alle betingelsene for et intakt polymer er oppfylt. Det er imidlertid unødvendig å teste lengden på polymeren og verifisere naboforhold da polymeren gjennom simuleringen behandles på en måte som gjør at disse ikke vil endres. "fastfast" er uten disse to stegene, men ellers identisk til "fast".
#
# Forskjellen i kjøretid kan sees ved å ta et enkelt polymer som eksempel og printe kjøretiden for de to forskjellige versjonene. I dette tilfellet har vi brukt et av polymerene fra oppgave 1 som eksempel. Her er N=15 og N_S=1000.

# %%
startf = time.time()
bf = N_simuleringer_f(15, 1000)[0]
endf = time.time()

starts = time.time()
bs = N_simuleringer_s(15, 1000)[0]
ends = time.time()

startff = time.time()
bff = N_simuleringer_ff(15, 1000)[0]
endff = time.time()

divf = (ends-starts) / (endf-startf)
divff = (ends-starts) / (endff-startff)

print("Kjøretid treg kode: ", ends-starts, "sek")
print("Kjøretid rask kode: ", endf-startf, "sek")
print("Kjøretid superrask kode: ", endff-startff, "sek")

print(f"Den raske koden er {divf} ganger raskere enn den trege for den valgte test-polymeren")
print(f"Den kjemperaske koden er {divff} ganger raskere enn den trege for den valgte test-polymeren")
# Out:
# Kjøretid treg kode:  0.8777427673339844 sek
# Kjøretid rask kode:  0.10144901275634766 sek
# Kjøretid superrask kode:  0.13425493240356445 sek
# Den raske koden er 8.652058245673407 ganger raskere enn den trege for den valgte test-polymeren
# Den kjemperaske koden er 6.537880967348954 ganger raskere enn den trege for den valgte test-polymeren

# %% [markdown]
# Vi kan se at den prosentvise forskjellen er betydelig, men opplever likevel at samtlige koder gjør jobben på akseptabel tid. Det virkelige forskjellen kommer nemlig ikke til syne før vi kjører større simuleringer hvor vi også endrer lengden på polymeren. På korte polymerer er det ikke spesielt tidkrevende å iterere gjennom alle monomerene sammenlignet med å bruke numpy-operatorene. Etterhvert som polymerene vokser vil imidlertid de nøstede løkkene øke kjøretiden betraktelig, samtidig som tidsbruken for vektoroperasjonene forblir lav og noenlunde konstant.
#
# Nedenfor er tiden per simulason som funksjon av polymerens lengde N for "fast" og "slow" (N_s = 100 = konst.) plottet sammen. Det er også inkludert et plott hvor vi ser den relative hastighetsforskjellen i kjøretid for de to kodene. Denne viser tydelig hvordan "slow" i økende grad blir ugunstig ved høyere N.

# %%
d = 100 #number of datapoints

"""-------------------Tid som funksjon av N-------------------"""
N_array = np.linspace(5,100,d,dtype=int)

time_f = np.zeros(d)
time_s = np.zeros(d)
div_array = np.zeros(d)
count = 0

for N in N_array:
    start_f = time.time()
    poly_f = N_simuleringer_f(N, 100)[0]
    end_f = time.time()
    
    time_f[count] = end_f-start_f
    
    start_s = time.time()
    poly_s = N_simuleringer_s(N, 100)[0]
    end_s = time.time()
    
    poly_s = N_simuleringer_s(N, 100)[0]
    
    time_s[count] = end_s-start_s
    div_array[count] = (end_s-start_s) / (end_f-start_f)
    
    count +=1


plt.plot(N_array, time_f, 'g', label = "Fast function")
plt.plot(N_array, time_s, 'r', label = "Slow function")
plt.xlabel('Length of polymer, N')
plt.ylabel('Time per simulation set (N_s = 100) [sek]')
plt.title('Time per simultion as a function of N, fast vs. slow', fontsize=14)
plt.grid(True)
plt.legend()
plt.show()

plt.plot(N_array, time_f, 'g', label = "Fast function")
plt.xlabel('Length of polymer, N')
plt.ylabel('Time per simulation set (N_s = 100) [sek]')
plt.title('Time per simultion as a function of N, fast', fontsize=14)
plt.grid(True)
plt.legend()
plt.show()

plt.plot(N_array, div_array)
plt.xlabel('Length of polymer, N')
plt.ylabel('Relative speed (Slow/Fast)')
plt.title('Relative speed fast vs. slow as a function of N', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Simulasjon av polymerfolding uten energi
#
# Vi kjører nå to simuleringer av en rett polymer med 15 monomerer for å se hvordan den foldes. I den første simuleringen blir den forsøkt foldet 4 ganger og i den andre blir den forsøkt foldet 1000 ganger. Vi illustrerer deretter sluttpolymeren i de to simuleringene og ser om vi kan bruke dette til å si noe om hvordan valg av rotasjonsforsøk påvirker foldingen.

# %%
a = N_simuleringer(15, 4)[0]
b = N_simuleringer(15, 1000)[0]

illustratePolymer(a, 'Polymer forsøkt foldet 4 ganger')
illustratePolymer(b, 'Polymer forsøkt foldet 1000 ganger')

# %% [markdown]
# Figurene viser sluttposisjonen til et polymer med 15 monomerer (N=15) som er forsøkt rotert henholdsvis 4 og 1000 ganger. Polymeren med klart flest rotasjonsforsøk er som forventet mer sammenkveilet og kompakt. Det er imidlertid verdt å merke seg at selv om polymer b er forsøkt rotert 250 ganger mer enn polymer a, viser plottet langt under 250 ganger flere vellykkede rotasjoner.
#
# Dette skyldes at det blir færre gyldige rotasjoner etter de første rotasjonsforsøkene og gjennomførte rotasjoner per rotasjonsforsøk vil bli lavere for polymeren med mange rotasjonsforsøk. Forskjellen i prosentandel gyldige rotasjoner blir tydelig i dette tilfellet hvor vi inkluderer polymer a med kun 4 forsøk. Sannsynligheten for at de fire første rotasjonene er vellykkede er høy sammenlignet med et allerede kveilet polymer. For svært lave N_s vil alle rotasjonsforsøkene skje i stadiet hvor de aller fleste kveilingene fører til færre muligheter. Prosentandelen vellykkede vil derfor synke med N_s i dette området.
#
# Det er imidlertid ikke gitt at høyere N_s alltid vil gi lavere prosentandel gyldige rotasjoner for høyere N_s. Vi sjekker dette ved å lage en funksjon, prosentGyldigRotasjon, som utfører tilsvarende simulering for tre ulike høye N_s, 500, 1000 og 1500, og returnerer prosentandelen gyldige rotasjoner for ulike lengder N. Deretter plotter vi resultatene.

# %%
def prosentGyldigRotasjon(N_end, N_s):
    N_list = np.arange(3, N_end + 1, 1) #Gir ikke noe å se på under 3
    prosent = np.zeros(len(N_list))

    for i in range(len(N_list)):
        N = N_list[i]
        prosent[i] = N_simuleringer(N, N_s)[1]/N_s
    
    return N_list, prosent

N_s_list = [500, 1000, 1500]
N_end = 100

plt.xlabel('N')
plt.ylabel('Prosentandel gyldige rotasjoner')
plt.title('Prosentandel gyldige rotasjoner for polymer med lengde N')

for i in N_s_list:
    N_liste, prosent = prosentGyldigRotasjon(N_end, i)
    plt.plot(N_liste, prosent, label = 'Ns = ' + str(i))

plt.legend()
plt.show()

# %% [markdown]
# Vi ser fra figuren at grafene utvikler seg likt og overlapper i stor grad, noe som antyder at ved store N_s har det lite å si for prosentandel gyldige rotasjoner. Polymerer vil for de første forsøkene ha svært mange muligheter for vellykkede rotasjoner. I en startperiode vil de aller fleste vellykkede rotasjonene gi mindre sannsynlighet for at den neste kan være vellykket. Etter polymeren har gjennomført noen initielle foldinger vil det derimot bli en relativt fast fordeling mellom gyldige og ugyldige rotasjoner ved konstant N, og størrelsen på N_s får ingen betydning så lenge den er tilstrekkelig stor til at startfasen får liten betydning.
# når N_s er stort får startfasen liten betydning for resultatet.
#
# For høyere N_s vil polymerens lengde ha mer å si for prosentandelen vellykkede rotasjoner. I plottet under er prosentandel gyldige rotasjoner for polymer med lengde N plottet for tre forskjellige (men høye) N_s. For et kort polymer vil den ikke bli spesielt innviklet og har stor sannsynlighet for å vikle seg ut igjen, og dermed høyere prosent antall velykkede rotasjoner. Lange polymerer vil imidlertid etter hvert kunne havne i et stadie hvor veldig mange av monomerene er mer eller mindre innespærret og gir dermed få gyldige rotasajoner. Prosentandelen vellykkede rotasjoner blir dermed lavere for lange polymerer.

# %% [markdown]
# ## Polymerens energi
#
# Vi har til nå i prosjektet ikke tatt hensyn til vekselvirkninger mellom monomerene i polymerene, som kan gi opphav til en energiendring ved rotasjoner. Vi inkulderer dette i modellen ved å lage en vekselsvirkningsmatrise V, i funksjonen make_V(polymer, v_Energy), som angir vekselsvirkning mellom to monomerer. Indeksen V[i][j] viser vekselvirkningen mellom monomer i og j. Vi antar at monomerer kun vekselvirker hvis de er nærmeste naboer og at de ikke opplever vekselvirkning fra monomerene ved siden av seg i rekken, altså ikke mellom monomerer som har kovalent binding, eller fra seg selv. Derfor må elementene i diagonalen, over-, og underdiagonalen være lik null. Videre må matrisen være symmetrisk siden vekselvirkningen mellom monomer i og j må være lik vekselvirkningen mellom j og i (V[i][j] = V[j][i]). Når vi lager V i denne funksjonen antar vi at alle elementene som ikke er lik null har samme verdi, men dette er ikke egentlig noe krav. Vi vil se mer på dette senere i oppgaven.

# %%
#making a matrix V 
def make_V(polymer, v_Energy):  
    N  = len(polymer)
    V = np.full((N, N), v_Energy)
    #zero elements in diagonal and upper- aand lower diagonal
    for i in range(N):
        for j in range(N):
            if i == j:
                V[i][j]=0
            elif i == j+1:
                V[i][j]=0
                V[j][i]=0
    return V

# %% [markdown]
# For å finne energien til et polymer må vi summere over alle vekselsvirkningene. Dette gjør vi med å multiplisere V-matrisen med operatoren b. b er en matrise med verdien 1 i koordinatene hvor vi har vekselsvirkende monomerer og null ellers. For eksempel vil vekselvirkning mellom monomer x og y gi veriden 1 i koorinatene (x-1, y-1) og (y-1, x-1) i matrisen b. Man finner da energien fra summen av elementene i den nye matrisen delt på to, slik at vekselvirkning mellom to monomerer ikke teller to ganger.

# %%
#calculetes total energy of a polymer
def calculate_energy(polymer, V):
    polymer = np.copy(polymer)
    N = len(polymer)
    b = np.zeros((N, N))
    #making the b operator/E_matrix
    E_matrix = np.zeros((N, N))
    #inserting value 1 to the b operator, where there is interaction between mormones.
    for i in range(len(polymer)): 
        for j in range(i+2, len(polymer)):
            dx = abs(polymer[i][0] - polymer[j][0])
            dy = abs(polymer[i][1] - polymer[j][1])
            if ((dx == 1 and dy == 0) or (dx == 0 and dy == 1)):
                b[i][j] = 1
                b[j][i] = 1
    E_matrix = 1/2 * (V * b)
    E = np.sum((E_matrix))
    return E

# %% [markdown]
# For å simulere hvordan et polymer folder seg i en gitt temperatur, i en modell der vi også tar hensyn til energiendringen,
# bruker vi Metropolis algoritmen. Denne tar også utgangspunkt i tilfeldige rotasjoner, men roterer bare til posisjoner med
# høyere energi med en viss sannsynlighet. Dette gjør vi ved å bruke forholdet mellom sannsynligheten for at polymeren ligger i
# de to ulike tilstandene. Forholdet er gitt ved $$e^{\beta \Delta E}$$ der beta er $$1/(k_b * T)$$ og deltaE er forskjellen i energi i
# de to tilstandene. Er energien til den roterte polymeren høyere enn den opprinnelige vil polymeren kun oppdateres dersom et tilfeldig generert tall mellom 0 og 1 er lavere enn dette forholdet, og har dermed simulert tilfeldige flukseringer til tilstander med større energi. Det er verdt å legge merke til at sannsynligheten for disse flukseringene er avhengig av temperaturen.

# %%
#simulates polymers, where monomers are interacting, using Monte Carlo
def metropolisalgoritmen(polymer, N_s, V, T): 
    polymer = np.copy(polymer)
    beta = 1/(1.38 * 10**(-23) * T) #1/(k_b * T), [T] = K
    
    E_array = np.zeros(N_s + 1)
    E = calculate_energy(polymer, V)
    i = 0

    #twisting polymer and updates polymer if the new twisted polymer satisfies the "ruels" of polymerIntact(...)
    while i < N_s:
        koord = polymer[np.random.randint(1, len(polymer)-1)] #excluding the monomers at the ends
        rot = np.random.randint(0, 2)
        twisted_polymer = rotatePolymer(polymer, koord, rot)
        if polymerIntact(twisted_polymer, N):
            i += 1
            E_new = calculate_energy(twisted_polymer, V)
            if E_new < E:
                polymer = twisted_polymer
                E = E_new
            elif np.random.uniform(0, 1) < math.exp(-beta*(E_new - E)): 
                polymer = twisted_polymer
                E = E_new
            E_array[i] = E
    return polymer, E_array

# %% [markdown]
# ## Simulering av polymerfolding med energi
#
# Vi bruker nå de nye definerte funksjonene til å simulere en polymerfolding med 5000 gyldige rotasjoner, med hensyn til at rotasjoner til høyere energi ikke alltid vil gå gjennom. Vi kjører simulasjonen for tre temperaturer: 10K, 100K og 300K. Vi starter i alle tilfellene med en rett polymer med 20 monomerer. Vi plotter energi som funksjon av antall Monte Carlo-steg for simulasjonene ved ulike temperaturer, samt illustrerer sluttpolymeren.

# %%
#sets constants
N = 20
polymer_start = makeStraightPolymer(N)
N_s = 5000
vekselvirkning = -4.0 * 10**(-21) #J
T_lav = 10 #K
T_middels = 100 #K
T_hoy = 300 #K
V_matrise = make_V(polymer_start, vekselvirkning)

#Plotting energy as function of Monte Carlo-steps 
plt.xlabel('Antall Monte Carlo-steg [t]')
plt.ylabel('Energi [J]')
plt.title('Energi som funksjon av antall Monte Carlo-steg')

polymer_T_lav, energi_T_lav = metropolisalgoritmen(polymer_start, N_s, V_matrise, T_lav)
polymer_T_middels, energi_T_middels = metropolisalgoritmen(polymer_start, N_s, V_matrise, T_middels)
polymer_T_hoy, energi_T_hoy = metropolisalgoritmen(polymer_start, N_s, V_matrise, T_hoy)
 
t = np.arange(1, len(energi_T_lav)+1, 1) #monte carlo-steps

plt.plot(t, energi_T_lav, label = f'T = {T_lav} K')
plt.plot(t, energi_T_middels, label = f'T = {T_middels} K')
plt.plot(t, energi_T_hoy, label = f'T = {T_hoy} K')

plt.legend()
plt.show()

#Ilustrateing polymers of different energies
illustratePolymer(polymer_T_lav, f'Sluttpolymer ved T = {T_lav}')
illustratePolymer(polymer_T_middels, f'Sluttpolymer ved T = {T_middels}')
illustratePolymer(polymer_T_hoy, f'Sluttpolymer ved T = {T_hoy}')

# %% [markdown]
# Vi ser at polymeren som folder seg i lavest temperatur, 10 K, synker fort til et gitt energinivå der den blir liggende. En rett polymer vil ha mange muligheter til å foldes til tilstander med lavere energi og den vil foldes til den når et lokalt energiminimum. I et lokalt minimum vil ikke polymeren ha noen gyldige rotasjoner til posisjoner med lavere energi. I denne tilstanden vil polymeren være sammenkrøllet fordi dette gir mange vekselvirkninger, noe vi kan se i den illustrerte sluttposisjonen. Den er da avhengig av tilfeldige fluktureringer til høyere energinivåer for å endres, noe som er lite sannsynlig for lave temperaturer. Vi ser at dette er tilfelle fra ligningen $$\frac{f(P_n)}{f(P_i)}=e^{-\beta \Delta E}$$ oppgitt i oppgavebeskrivelsen som gir lav sannsynlighet for rotasjon ved lav temperatur. Vi kan få simuleringer der dette skjer, men polymeren vil da typisk hoppe ned igjen til et lokalt energiminimum direkte etterpå. Dette kan vi se i simuleringen ved temperatur 100K. Nå er sannsynligheten for fluktureringer stor nok til at antallet øker, men den stabiliserer seg fort ned igjen til det samme eller et annet lokalt energiminimum. Dermed blir også denne sannsynligvis relativt sammenkrøllet, noe som passer bra med illustrasjonen. For høye temperaturer er rotasjoner til høyere energinivåer svært sannsynlig og vi får et mye mer tilfeldig mønster i energien, noe vi ser i grafen ved 300K. Det blir da tilfeldig hvor sammenkrøllet sluttpolymeren blir.

# %% [markdown]
# Grafen vi nå har plottet antyder at forventningsverdien til energien er større for høyere temperaturer. Dette kan forklares av at ved høyere temeraturer vil det bli flere rotasjoner mot høyere energier, og dermed også flere tilfeller med høyere energinivåer. For å sjekke dette mer presist kan
# vi sette opp forventningsverdien som en funksjon av temperaturen. Vi ser på temperaturer på intervallet [10, 1000]. Vi legger også inn standardavviket for de ulike temperaturene.

# %%
#calculate SD and E[x] in a interval of diffrent tempratures
def forventningsVal_E(polymer, N_s, V, T_arr):
    forventningsverdi = np.zeros(len(T_arr))
    standardavvik = np.zeros(len(T_arr))
    
    #calculate SD and E[x] for each temprature and adding the results to lists
    for i in range(len(T_arr)): 
        E_ar = metropolisalgoritmen(polymer, N_s, V, T_arr[i])[1]
        E_ar = E_ar[1000:] #removes the first 1000 energy elements
        forventningsverdi[i] = np.average(E_ar)
        standardavvik[i] = np.sqrt(np.average(E_ar**2) - (np.average(E_ar))**2)

    return forventningsverdi, standardavvik

N = 20
N_s = 5000
v_Energy = -4.0 * 10**(-21)

polymer_start = makeStraightPolymer(N)
V = make_V(polymer_start,v_Energy)

T_list = np.arange(10,1000,30)

forventningsverdi, standardavvik = forventningsVal_E(polymer_start, N_s, V, T_list)

#Plotting E[energy] as a function of temprature, with the SD as errorbars in y-direction
plt.xlabel('Temperatur [K]')  
plt.ylabel('Energi [J]') 
plt.title('Energi som funksjon av temperatur') 

plt.errorbar(T_list, forventningsverdi, yerr = standardavvik, label = 'Forventningsverdi') 

plt.legend()
plt.show()
# Out:
# <ipython-input-39-bc75e4b6b36e>:11: RuntimeWarning: invalid value encountered in sqrt
#   standardavvik[i] = np.sqrt(np.average(E_ar**2) - (np.average(E_ar))**2)

# %% [markdown]
# Vi ser at grafen går godt overens med det vi forutså, altså at forventningsenergien til energien øker med temperaturen. Starten av grafen, ved de laveste temperaturene, avviker derimot fra dette. Dette kan forklares ved at polymeren havner i et lokalt energiminimum den ikke kommer seg ut av fordi temperaturen er svært lav. Polymeren starter å foldes fra en rett polymer med høy energi, og kan havne i energiminimum som er svært ulikt fra hva man kan forvente under de lave temperaturene. Her ser vi også at standardavviket blir satt til null. Vi har kuttet de 1000 første stegene der polymeren foldes til posisjonen polymeren har i et lokalt energiminimum. Alle energiene vi bruker for å finne standardavviket er derfor tilnærmet like, med forbehold om at det kan ha skjedd fluktureringer. Uttrykket vi har brukt i kvadratroten tar dermed inn for små tall til at de kan behandles matematisk riktig, og vi får kvadratroten av negative tall. Numpy feilbehandler dette ved å sette standardavvik til null, som vi har valgt å beholde fordi det vil være en god tilnærming. Det er tilfeldigheter som styrer hvilket lokalt energiminimum polymeren havner i, og vi kan få store sprik i grafen. For å bedre kunne si noe om forventningsverdien i lave temperaturer holder det derfor ikke å se på en enkelt simulasjon slik vi har gjort her, men må heller se på flere slik at vi kan få et gjennomsnitt av de lokale energiminimumene. I koden under kjøres flere simulasjoner ved temperaturen 10K og ellers de samme forutsetningene, for å bedre kunne si noe om forventningsverdien her.

# %%
#setting constants
N = 20
N_s = 5000
v_Energy = -4.0 * 10**(-21)
T = 10

polymer_start = makeStraightPolymer(N)
V = make_V(polymer_start,v_Energy)        
t = np.arange(0, N_s + 1, 1)

#plotting energy as function of temperature 
plt.xlabel('t steg')  
plt.ylabel('Energi [J]') 
plt.title('Energi som funksjon av temperatur') 
for i in range(10):
    plt.plot(t, metropolisalgoritmen(polymer_start, N_s, V, T)[1], label = str(i+1))
plt.legend()
plt.show()

# %% [markdown]
# Vi ser tydelig i grafen at polymeren legger seg i ulike energiminimum i de ulike simulasjonene. Tilfeldigheter tidlig i foldingen avgjør hvilket minimum polymeren treffer. For å si noe om forventningsverdien er det dermed mest hensiktsmessig å ta et gjennomsnitt av disse. En annen mulighet vi vil vurdere er å la en rett polymer foldes i synkende temperaturen, tilsvarende en avkjøling av polymeret. Vi ser nå på den lengste distansen over polymeret. Denne har sammenheng med energien da distansen blir lenger over en polymer som er mindre sammenkrøllet og dermed har høyere energi. Vi lager en funksjon maxDistance(polymer) som tar inn en polymer og returnerer den lengste distansen mellom to monomerer. Vi oppdaterer også Metropolisalgoritmen til å lagre alle de lengste distansene over polymeret som foldes i et nytt array.
#
# Deretter kjører vi to litt ulike funksjoner for å finne forventningverdien for den lengste distansen over polymeren, d, som funksjon av temperaturen. I den første starter vi med en rett polymer i hver av temperaturene og kutter de 1000 første stegene fordi disse ikke vil være representative for den gjeldene temperaturen. Vi starter i lave temperaturer og øker, men dette har egentlig ikke noe betydning for resultatet siden vi alltid starter med et rett polymer og forventningsverdien for hver temperatur blir uavhengig av hverandre. I den andre funksjonen starter vi i den høyeste temperaturen med et rett polymer og går deretter nedover i temperatur. Vi starter ikke nå med et rett molekyl for den lavere temperaturen, men bruker heller sluttpolymeren simulasjonen ved hakke høyere temperatur. Den rette polymeren er mer sannsynlig å finne ved høy temperatur og gir dermed en mer realistisk simulasjon.

# %%
#finding the longest distance between two monomers in a polymer
def maxDistance(polymer):
    maxDistance = 1
    #iterating trough each monomer for each monomer and updates maxDistance
    for j in range(len(polymer)-1):
        for k in range(j+2, len(polymer)): #not checking the neighbor, since the distance is known and 1 
            d = np.linalg.norm(polymer[j] - polymer[k])
            if d > maxDistance:
                maxDistance = d
    return maxDistance
    
#same as the metropolisfunction, but using the maxDistance function to calculate the distance as well
def metropolisWithDistance(polymer, N_s, V, T): 
    polymer = np.copy(polymer)
    beta = 1/(1.38*10**(-23) * T) #1/(k_b * T), [T] = K
    
    E_array = np.zeros(N_s + 1) 
    d_array = np.zeros(N_s + 1)
    E = calculate_energy(polymer, V)
    d_array[0] = maxDistance(polymer)
    i = 0
    while i < N_s:
        koord = polymer[np.random.randint(1, len(polymer)-1)] 
        rot = np.random.randint(0, 2)
        twisted_polymer = rotatePolymer(polymer, koord, rot)
        if polymerIntact(twisted_polymer, N):
            i += 1
            E_new = calculate_energy(twisted_polymer, V)
            if E_new < E:
                polymer = twisted_polymer
                E = E_new

            elif np.random.uniform(0, 1) < math.exp(-beta*(E_new - E)): 
                polymer = twisted_polymer
                E = E_new
            E_array[i] = E
            d_array[i] = maxDistance(polymer) #making an array with distances so that we can calculate the mean value later
            
    return polymer, E_array, d_array 

#Calculates E[maxDistance] in the same way as for energy
def forventningsVal_d(polymer, N_s, V, T_arr):
    forventningsverdi = np.zeros(len(T_arr))
    
    for i in range(len(T_arr)):
        D_ar = metropolisWithDistance(polymer, N_s, V, T_arr[i])[2]
        D_ar = D_ar[1000:]
        forventningsverdi[i] = np.mean(D_ar)

    return forventningsverdi
#Calculates E[maxDistance] in the same way as for energy, but in the opposite temp. interval 
def forventningsVal_d_reversed(polymer, N_s, V, T_arr):
    forventningsverdi = np.zeros(len(T_arr))
    
    for i in range(len(T_arr)):
        polymer, E_var, D_ar = metropolisWithDistance(polymer, N_s, V, T_arr[i])
        D_ar = D_ar[1000:]
        forventningsverdi[i] = np.average(D_ar)

    return forventningsverdi

N = 20
N_s = 5000
T_list = np.arange(10, 1000, 50)
T_list_reversed = np.flip(T_list)

polymer_start = makeStraightPolymer(N)
vEnergy = np.random.randint(-6, -2) * 10**(-21)
V = make_V(polymer_start, vEnergy)
 
#timing
start = time.time()

forventningsverdi_d = forventningsVal_d(polymer_start, N_s, V, T_list)

end = time.time()
print("Execution time of the 1. program is- ", end-start, " seconds")

#timing
start = time.time()

forventningsverdi_d_reversed = forventningsVal_d_reversed(polymer_start, N_s, V, T_list_reversed)

end = time.time()
print("Execution time of the 2. program is- ", end-start, " seconds")

#Plotting E[maxDistance] and E[maxDistance] reversed as function of T

plt.xlabel('Temperatur [K]')  
plt.ylabel('Distanse') 
plt.title('Forventningsverdi av D som funksjon av T') 

plt.plot(T_list, forventningsverdi_d, label = 'Lav til høy')
plt.plot(T_list_reversed, forventningsverdi_d_reversed, label = 'Høy til lav')

plt.legend()
plt.show()
# Out:
# Execution time of the 1. program is-  139.43932151794434  seconds
# Execution time of the 2. program is-  138.37346196174622  seconds

# %% [markdown]
# Vi ser at simuleringen som alltid tar utgangspunkt i en rett polymer har mye mer variasjon for de lavere temperaturene. Den andre metoden, der vi lagrer sluttpolymerene og bruker den som startpolymer videre, gir en jevnere graf. Når vi starter med en rett polymer vil det være tilfeldigheter som bestemmer i hvilket lokalt energiminimum polymeren havner, slik vi har diskutert tidligere, noe som skaper store variasjoner.
# Vi risikerer da at polymeren havner i et lokalt energiminimum som har for høy energi til å være representativt i en reel situasjon. Polymerene vi finner ved lave temperaturer vil typisk allerede være sammenkrøllet og på et energinivå under noen av de lokale energiminimumene vi risikerer at de havner i ved å starte med en rett polymer. Ved å starte med et polymer som er foldet vil polymeren havne i et realistisk lokalt energiminimum og gi en mer korrekt framstilling av distansen. Videre ser vi at det er en tydelig trend på at distansen over polymeren øker med temperaturen. Dette forklares, som tidligere, av at høyere temperatur gir flere rotasjoner til tilstander med høyere energi som også er mindre sammenkveilet.

# %% [markdown]
# Vi har til nå sett på eksempler der alle elementene i V-matrisen som ikke er null er like. Dette er som tidligere nevnt derimot ikke noe krav, det eneste kravet er at den er symetrisk. Vi skal derfor også se på et tilfelle der vekselvirkningen mellom monomer 2 og 5 og mellom monomer 7 og 10 er fire ganger så stor som mellom de andre monomerene. Vekselvirkningen mellom de resterende beholder vi lik som i forrige oppgave og ser på et polymer med 20 monomerer. Vi velger en relativt høy temperatur slik at polymeren ikke skal legge seg i lokale minimum som ligger langt fra de globale (der 2 og 5, og 7 og 10 er nærmeste naboer). Vi kjører tre simulasjoner og illustrer sluttpolymeren.

# %%
N = 20
T = 300
N_s = 10_000
vekselvirkning = -4.0 * 10**(-21) #J
V_different = make_V(polymer_start, vekselvirkning)

#changing elements in V-matrix
k = vekselvirkning * 4
V_different[2-1][5-1], V_different[5-1][2-1], V_different[7-1][10-1], V_different[10-1][7-1] = k, k, k, k

#preformes 3 simulations 
for i in range(3):
    polymer_vElementUnlike = metropolisalgoritmen(makeStraightPolymer(20), N_s, V_different, T)[0]
    illustratePolymer(polymer_vElementUnlike, name = str(i + 1) + '. simulering')

# %% [markdown]
# Vi ser her at i de fleste simuleringene vil monomer 2 ligge ved siden av monomer 5, og monomer 7 ligge ved siden av monomer 10. Fordi det kan være rotasjoner som ikke påviker posisjonen til disse monomerene forhold til hverandre, som polymeren kan flukturere rundt ved den relativt høye temperaturen vi har i simuleringen, trenger ikke dette være lokale energiminimum. Rotasjoner som fjerner vekselvirkninger mellom de nevnte monomerene vil derimot gi mye større energidifferanse og er derfor mindre sannsynlige. Vi ender da med å få mange simuleringer der de er nærmeste naboer.

# %% [markdown]
# ## Konklusjon
#
# Vi har nå sett på hvordan man kan simulere en forenkled polymerfolding i to dimensjoner og hvordan temperaturen i omgivelsene er med på å påvirke energien til polymeren og da også hvordan den blir seende ut. En polymer som ble formet i høy tempratur roterte vekk fra seg selv og strakk seg ut, mens en polymer i lavere temperatur krøllet seg mer sammen. Vi så også på forskjellen mellom å forme en polymer i økende og avtakende temperatur. Polymerer i lave temperaturer (rundt 10K) havnet i et energiminimum, som de ikke kom seg ut av,  Vi så at dersom man lar polymeren formes ved oppvarming fra lave temperaturer (10K) vil dette medføre  Fra resultatene våre i (2g og 2h) så vi at ....
